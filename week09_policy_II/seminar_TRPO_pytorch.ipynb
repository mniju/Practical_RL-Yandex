# %%
# # in google colab uncomment this

# import os

# os.system('apt-get install -y xvfb')
# os.system('wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall18/xvfb -O ../xvfb')
# os.system('apt-get install -y python-opengl ffmpeg')
# os.system('pip install pyglet==1.2.4')

# launch XVFB if you run on a server
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    # %env DISPLAY = : 1

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import gym

env = gym.make("Acrobot-v1")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n
print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# Observation Space Box(6,)
# Action Space Discrete(3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plt.imshow(env.render('rgb_array'))

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $ \pi_\theta(a|s) $.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
class TRPOAgent(nn.Module):
    def __init__(self, state_shape, n_actions, hidden_size=32):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple: 
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        nn.Module.__init__(self)

        #<your network here >
        self.fc1 = nn.Linear(state_shape[0],256)
        self.fc2 = nn.Linear(256,hidden_size)
        self.fc3 = nn.Linear(hidden_size,n_actions)

    def forward(self, states):
        """
        takes agent's observation (Variable), returns log-probabilities (Variable)
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """

        # Use your network to compute log_probs for given state
        x = F.relu(self.fc1(states))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        #print(x.shape)
        #print(x)
        log_probs = F.log_softmax(x,dim=1)
        return log_probs

    def get_log_probs(self, states):
        '''
        Log-probs for training
        '''

        return self.forward(states)

    def get_probs(self, states):
        '''
        Probs for interaction
        '''

        return torch.exp(self.forward(states))

    def act(self, obs, sample=True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from \pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        probs = self.get_probs(Variable(torch.FloatTensor([obs]))).data.numpy()

        if sample:
            action = int(np.random.choice(n_actions, p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]


agent = TRPOAgent(observation_shape, n_actions)

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(Variable(torch.FloatTensor([env.reset()])))
assert isinstance(
    log_probs, Variable) and log_probs.requires_grad, "qvalues must be a torch variable with grad"
assert len(
    log_probs.shape) == 2 and log_probs.shape[0] == 1 and log_probs.shape[1] == n_actions
sums = torch.sum(torch.exp(log_probs), dim=1)
assert (0.999 < sums).all() and (1.001 > sums).all()

# Demo use
print("sampled:", [agent.act(env.reset()) for _ in range(5)])
print("greedy:", [agent.act(env.reset(), sample=False) for _ in range(5)])
# Out:
# sampled: [(2, array([0.35947153, 0.2913053 , 0.3492231 ], dtype=float32)), (2, array([0.357119  , 0.29115525, 0.35172576], dtype=float32)), (0, array([0.35697815, 0.2918423 , 0.3511795 ], dtype=float32)), (0, array([0.35854623, 0.29162666, 0.34982714], dtype=float32)), (2, array([0.3569325 , 0.29200277, 0.35106468], dtype=float32))]
# greedy: [(0, array([0.358427 , 0.2915341, 0.3500389], dtype=float32)), (0, array([0.35758692, 0.29114956, 0.3512635 ], dtype=float32)), (0, array([0.3553263 , 0.29117334, 0.35350037], dtype=float32)), (0, array([0.3558737 , 0.29118684, 0.35293943], dtype=float32)), (0, array([0.35740367, 0.29063135, 0.35196495], dtype=float32))]

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = []
    for param in model.parameters():
        params.append(param.data.view(-1))

    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.size())))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].view(param.size()))
        prev_ind += flat_size

# %% [markdown]
# Compute cummulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal


def get_cummulative_returns(r, gamma=1):
    """
    Computes cummulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
# simple demo on rewards [0,0,1,0,0,1]
get_cummulative_returns([0, 0, 1, 0, 0, 1], gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: act - the function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, done, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if done or total_timesteps == n_timesteps:
                path = {"observations": np.array(obervations),
                        "policy": np.array(action_probs),
                        "actions": np.array(actions),
                        "rewards": np.array(rewards),
                        "cumulative_returns": get_cummulative_returns(rewards),
                        }
                paths.append(path)
                break
    return paths

# %%
paths = rollout(env, agent, max_pathlength=5, n_timesteps=100)
print(paths[-1])
assert (paths[0]['policy'].shape == (5, n_actions))
assert (paths[0]['cumulative_returns'].shape == (5,))
assert (paths[0]['rewards'].shape == (5,))
assert (paths[0]['observations'].shape == (5,)+observation_shape)
assert (paths[0]['actions'].shape == (5,))
print('It\'s ok')
# Out:
# {'observations': array([[ 0.99746324, -0.07118348,  0.99723227,  0.07434922,  0.05132186,
#          0.07783075],
#        [ 0.99791875, -0.06448379,  0.99397806,  0.10957929,  0.01571766,
#          0.27064073],
#        [ 0.99927421, -0.03809267,  0.99387654,  0.1104963 ,  0.24284108,
#         -0.25690373],
#        [ 0.99960692,  0.02803571,  0.99990913,  0.01348046,  0.40199609,
#         -0.68825459],
#        [ 0.99489788,  0.10088709,  0.99333259, -0.11528388,  0.30949653,
#         -0.56856268]]), 'policy': array([[0.35865697, 0.2926023 , 0.3487408 ],
#        [0.35878274, 0.29423392, 0.3469834 ],
#        [0.3570532 , 0.29099935, 0.35194737],
#        [0.35443535, 0.2884733 , 0.35709134],
#        [0.3530431 , 0.2886237 , 0.35833317]], dtype=float32), 'actions': array([2, 0, 0, 1, 1]), 'rewards': array([-1., -1., -1., -1., -1.]), 'cumulative_returns': array([-5., -4., -3., -2., -1.])}
# It's ok

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be
# $$J_{surr}= {1 \over N} \sum\limits_{i=0}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, let's use cummulative returns instead of advantage for now:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=0}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Or alternatively, minimize the surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cummulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns
    :param: old_probs - batch of probabilities computed by old network
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    probs_for_actions = probs_all[torch.arange(
        0, batch_size, out=torch.LongTensor()), actions]
    old_probs_for_actions = old_probs[torch.arange(
        0, batch_size, out=torch.LongTensor()), actions]

    # Compute surrogate loss, aka importance-sampled policy gradient
    Loss = -torch.mean((probs_for_actions/old_probs_for_actions)*cummulative_returns)

    assert Loss.shape == torch.Size([])
    return Loss

# %% [markdown]
# We can ascend these gradients as long as our $pi_\theta(a|s)$ satisfies the constraint
# $$E_{s,\pi_{\Theta_{t}}}\Big[KL(\pi(\Theta_{t}, s) \:||\:\pi(\Theta_{t+1}, s))\Big]< \alpha$$
#
#
# where
#
# $$KL(p||q) = E _p log({p \over q})$$

# %%
def get_kl(agent, observations, actions, cummulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network
    :returns: scalar value of the KL-divergence
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    # Compute Kullback-Leibler divergence (see formula above)
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took
    old_log_probs = torch.log(old_probs+1e-10)

    #kl = <cumpute kullback-leibler >
    kl = torch.sum(old_probs * (old_log_probs-log_probs_all))/batch_size

    assert kl.shape == torch.Size([])
    assert (kl > -0.0001).all() and (kl < 10000).all()
    return kl

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy 
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """

    observations = Variable(torch.FloatTensor(observations))

    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    entropy = torch.sum(-probs_all * log_probs_all) / batch_size

    assert entropy.shape == torch.Size([])
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x, fullstep, max_kl):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    max_backtracks = 10
    loss, _, = f(x)
    for stepfrac in .5**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        actual_improve = new_loss - loss
        if kl.data.numpy() <= max_kl and actual_improve.data.numpy() < 0:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve Ax=b using conjugate gradients.
#
# In general, CG is an algorithm that solves Ax=b where A is positive-defined. A is Hessian matrix so A is positive-defined. You can find out more about them [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method)

# %%
from numpy.linalg import inv


def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros(b.size())
    rdotr = torch.sum(r*r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.sum(p*z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.sum(r*r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
# This code validates conjugate gradients
A = np.random.rand(8, 8)
A = np.matmul(np.transpose(A), A)


def f_Ax(x):
    return torch.matmul(torch.FloatTensor(A), x.view((-1, 1))).view(-1)


b = np.random.rand(8)

w = np.matmul(np.matmul(inv(np.matmul(np.transpose(A), A)),
                        np.transpose(A)), b.reshape((-1, 1))).reshape(-1)
print(w)
print(conjugate_gradient(f_Ax, torch.FloatTensor(b)).numpy())
# Out:
# [-18.67383091 -24.07102509 -42.06491357  11.38999762   1.57374639
#   14.77766929   4.70970379  44.64830099]
# [-18.680172  -24.069382  -42.058407   11.389226    1.5742568  14.783769
#    4.7202454  44.634914 ]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cummulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """

    # Here we prepare the information
    observations = Variable(torch.FloatTensor(observations))
    actions = torch.LongTensor(actions)
    cummulative_returns = Variable(torch.FloatTensor(cummulative_returns))
    old_probs = Variable(torch.FloatTensor(old_probs))

    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions,
                    cummulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([grad.view(-1) for grad in grads]).data

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently

        kl = get_kl(agent, observations, actions,
                    cummulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.view(-1) for grad in grads])

        kl_v = (flat_grad_kl * Variable(v)).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat(
            [grad.contiguous().view(-1) for grad in grads]).data

        return flat_grad_grad_kl + v * 0.1

    # Here we solveolve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

    neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)

    # Here we get the start point
    prev_params = get_flat_params_from(agent)

    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [get_loss(agent, observations, actions, cummulative_returns, old_probs),
                get_kl(agent, observations, actions, cummulative_returns, old_probs)]

    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)

    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ##### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count
from collections import OrderedDict

# this is hyperparameter of TRPO. It controls how big KL divergence may be between old and new policy every step.
max_kl = 0.01
numeptotal = 0  # this is number of episodes that we played.

start_time = time.time()

for i in count(1):

    print("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print("Made rollout")

    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])

    loss, kl = update_step(agent, observations, actions,
                           returns, old_probs, max_kl)

    # Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = OrderedDict()
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
    i += 1
# Out:
# ********** Iteration 1 ************
# Rollout
# Made rollout
# Total number of episodes:                 101
# Average sum of rewards per episode:       -495.029702970297
# Std of rewards per episode:               29.82372483909597
# Time elapsed:                             0.27 mins
# KL between old and new distribution:      0.009998239
# Entropy:                                  1.0768735
# Surrogate loss:                           248.4067
#
# ********** Iteration 2 ************
# Rollout
# Made rollout
# Total number of episodes:                 201
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             0.53 mins
# KL between old and new distribution:      0.009992524
# Entropy:                                  1.074311
# Surrogate loss:                           249.9983
#
# ********** Iteration 3 ************
# Rollout
# Made rollout
# Total number of episodes:                 304
# Average sum of rewards per episode:       -485.2718446601942
# Std of rewards per episode:               43.561627849164154
# Time elapsed:                             0.81 mins
# KL between old and new distribution:      0.00999364
# Entropy:                                  1.048556
# Surrogate loss:                           244.75381
#
# ********** Iteration 4 ************
# Rollout
# Made rollout
# Total number of episodes:                 417
# Average sum of rewards per episode:       -442.01769911504425
# Std of rewards per episode:               80.43421786500747
# Time elapsed:                             1.08 mins
# KL between old and new distribution:      0.009988432
# Entropy:                                  1.0127932
# Surrogate loss:                           228.18816
#
# ********** Iteration 5 ************
# Rollout
# Made rollout
# Total number of episodes:                 546
# Average sum of rewards per episode:       -386.7751937984496
# Std of rewards per episode:               92.05452044027808
# Time elapsed:                             1.34 mins
# KL between old and new distribution:      0.009978642
# Entropy:                                  0.96996397
# Surrogate loss:                           203.7448
#
# ********** Iteration 6 ************
# Rollout
# Made rollout
# Total number of episodes:                 739
# Average sum of rewards per episode:       -258.0777202072539
# Std of rewards per episode:               66.81564747223625
# Time elapsed:                             1.62 mins
# KL between old and new distribution:      0.009970042
# Entropy:                                  0.9025115
# Surrogate loss:                           137.17535
#
# ********** Iteration 7 ************
# Rollout
# Made rollout
# Total number of episodes:                 974
# Average sum of rewards per episode:       -211.77021276595744
# Std of rewards per episode:               47.382984264681674
# Time elapsed:                             1.89 mins
# KL between old and new distribution:      0.009976686
# Entropy:                                  0.9043388
# Surrogate loss:                           110.77831
#
# ********** Iteration 8 ************
# Rollout
# Made rollout
# Total number of episodes:                 1229
# Average sum of rewards per episode:       -195.09411764705882
# Std of rewards per episode:               51.03984376614444
# Time elapsed:                             2.17 mins
# KL between old and new distribution:      0.00999392
# Entropy:                                  0.86440295
# Surrogate loss:                           103.79916
#
# ********** Iteration 9 ************
# Rollout
# Made rollout
# Total number of episodes:                 1517
# Average sum of rewards per episode:       -172.61805555555554
# Std of rewards per episode:               41.65616476448357
# Time elapsed:                             2.44 mins
# KL between old and new distribution:      0.009986187
# Entropy:                                  0.8261993
# Surrogate loss:                           90.94023
#
# ********** Iteration 10 ************
# Rollout
# Made rollout
# Total number of episodes:                 1845
# Average sum of rewards per episode:       -151.4481707317073
# Std of rewards per episode:               42.64734568780047
# Time elapsed:                             2.71 mins
# KL between old and new distribution:      0.009978669
# Entropy:                                  0.79693204
# Surrogate loss:                           81.36434
#
# ********** Iteration 11 ************
# Rollout
# Made rollout
# Total number of episodes:                 2208
# Average sum of rewards per episode:       -136.7520661157025
# Std of rewards per episode:               47.08077830509826
# Time elapsed:                             2.99 mins
# KL between old and new distribution:      0.009993608
# Entropy:                                  0.775006
# Surrogate loss:                           76.05787
#
# ********** Iteration 12 ************
# Rollout
# Made rollout
# Total number of episodes:                 2590
# Average sum of rewards per episode:       -129.89267015706807
# Std of rewards per episode:               40.366987946921554
# Time elapsed:                             3.26 mins
# KL between old and new distribution:      0.009990379
# Entropy:                                  0.79229593
# Surrogate loss:                           70.878494
#
# ********** Iteration 13 ************
# Rollout
# Made rollout
# Total number of episodes:                 2966
# Average sum of rewards per episode:       -131.98138297872342
# Std of rewards per episode:               34.587880274991655
# Time elapsed:                             3.53 mins
# KL between old and new distribution:      0.00997732
# Entropy:                                  0.7422405
# Surrogate loss:                           70.18182
#
# ********** Iteration 14 ************
# Rollout
# Made rollout
# Total number of episodes:                 3384
# Average sum of rewards per episode:       -118.61961722488039
# Std of rewards per episode:               31.75815154141008
# Time elapsed:                             3.79 mins
# KL between old and new distribution:      0.009986743
# Entropy:                                  0.71591157
# Surrogate loss:                           63.284386
#
# ********** Iteration 15 ************
# Rollout
# Made rollout
# Total number of episodes:                 3816
# Average sum of rewards per episode:       -114.74305555555556
# Std of rewards per episode:               29.509668815941378
# Time elapsed:                             4.06 mins
# KL between old and new distribution:      0.009981667
# Entropy:                                  0.6739652
# Surrogate loss:                           60.865864
#
# ********** Iteration 16 ************
# Rollout
# Made rollout
# Total number of episodes:                 4262
# Average sum of rewards per episode:       -111.11210762331838
# Std of rewards per episode:               35.809986664131536
# Time elapsed:                             4.33 mins
# KL between old and new distribution:      0.00997998
# Entropy:                                  0.65005237
# Surrogate loss:                           61.074623
#
# ********** Iteration 17 ************
# Rollout
# Made rollout
# Total number of episodes:                 4715
# Average sum of rewards per episode:       -109.37748344370861
# Std of rewards per episode:               30.49077775860729
# Time elapsed:                             4.59 mins
# KL between old and new distribution:      0.009973937
# Entropy:                                  0.6583344
# Surrogate loss:                           58.647625
#
# ********** Iteration 18 ************
# Rollout
# Made rollout
# Total number of episodes:                 5189
# Average sum of rewards per episode:       -104.4873417721519
# Std of rewards per episode:               23.875221696924296
# Time elapsed:                             4.86 mins
# KL between old and new distribution:      0.009997621
# Entropy:                                  0.6445334
# Surrogate loss:                           54.754116
#
# ********** Iteration 19 ************
# Rollout
# Made rollout
# Total number of episodes:                 5656
# Average sum of rewards per episode:       -106.06852248394004
# Std of rewards per episode:               28.586463279455415
# Time elapsed:                             5.13 mins
# KL between old and new distribution:      0.009992246
# Entropy:                                  0.6000928
# Surrogate loss:                           56.662956
#
# ********** Iteration 20 ************
# Rollout
# Made rollout
# Total number of episodes:                 6153
# Average sum of rewards per episode:       -99.6056338028169
# Std of rewards per episode:               24.238449269469285
# Time elapsed:                             5.40 mins
# KL between old and new distribution:      0.009985874
# Entropy:                                  0.5592053
# Surrogate loss:                           52.54215
#
# ********** Iteration 21 ************
# Rollout
# Made rollout
# Total number of episodes:                 6642
# Average sum of rewards per episode:       -101.25153374233129
# Std of rewards per episode:               30.36559986418591
# Time elapsed:                             5.66 mins
# KL between old and new distribution:      0.009974219
# Entropy:                                  0.54621255
# Surrogate loss:                           54.946014
#
# ********** Iteration 22 ************
# Rollout
# Made rollout
# Total number of episodes:                 7139
# Average sum of rewards per episode:       -99.6056338028169
# Std of rewards per episode:               33.368821946832654
# Time elapsed:                             5.93 mins
# KL between old and new distribution:      0.009983541
# Entropy:                                  0.52915955
# Surrogate loss:                           55.15814
#
# ********** Iteration 23 ************
# Rollout
# Made rollout
# Total number of episodes:                 7630
# Average sum of rewards per episode:       -100.83910386965377
# Std of rewards per episode:               36.30635346388575
# Time elapsed:                             6.20 mins
# KL between old and new distribution:      0.009998542
# Entropy:                                  0.49362534
# Surrogate loss:                           56.74522
#
# ********** Iteration 24 ************
# Rollout
# Made rollout
# Total number of episodes:                 8128
# Average sum of rewards per episode:       -99.40361445783132
# Std of rewards per episode:               35.218875959966205
# Time elapsed:                             6.46 mins
# KL between old and new distribution:      0.009989619
# Entropy:                                  0.4839175
# Surrogate loss:                           55.714325
#
# ********** Iteration 25 ************
# Rollout
# Made rollout
# Total number of episodes:                 8625
# Average sum of rewards per episode:       -99.60965794768612
# Std of rewards per episode:               38.6343399142181
# Time elapsed:                             6.73 mins
# KL between old and new distribution:      0.009986751
# Entropy:                                  0.47977206
# Surrogate loss:                           57.069954
#
# ********** Iteration 26 ************
# Rollout
# Made rollout
# Total number of episodes:                 9130
# Average sum of rewards per episode:       -98.01386138613861
# Std of rewards per episode:               34.56051953938585
# Time elapsed:                             7.00 mins
# KL between old and new distribution:      0.009989354
# Entropy:                                  0.43973267
# Surrogate loss:                           54.82615
#
# ********** Iteration 27 ************
# Rollout
# Made rollout
# Total number of episodes:                 9645
# Average sum of rewards per episode:       -96.08932038834952
# Std of rewards per episode:               29.92222576420008
# Time elapsed:                             7.26 mins
# KL between old and new distribution:      0.00998122
# Entropy:                                  0.39994258
# Surrogate loss:                           52.471096
#
# ********** Iteration 28 ************
# Rollout
# Made rollout
# Total number of episodes:                 10180
# Average sum of rewards per episode:       -92.46168224299065
# Std of rewards per episode:               29.633681408248496
# Time elapsed:                             7.53 mins
# KL between old and new distribution:      0.009974275
# Entropy:                                  0.40429202
# Surrogate loss:                           50.71485
#
# ********** Iteration 29 ************
# Rollout
# Made rollout
# Total number of episodes:                 10711
# Average sum of rewards per episode:       -93.16572504708098
# Std of rewards per episode:               31.83796713089545
# Time elapsed:                             7.80 mins
# KL between old and new distribution:      0.009987084
# Entropy:                                  0.35854852
# Surrogate loss:                           51.809395
#
# ********** Iteration 30 ************
# Rollout
# Made rollout
# Total number of episodes:                 11255
# Average sum of rewards per episode:       -90.91360294117646
# Std of rewards per episode:               25.570869632914732
# Time elapsed:                             8.06 mins
# KL between old and new distribution:      0.009981236
# Entropy:                                  0.3288064
# Surrogate loss:                           48.84459
#
# ********** Iteration 31 ************
# Rollout
# Made rollout
# Total number of episodes:                 11818
# Average sum of rewards per episode:       -87.81172291296625
# Std of rewards per episode:               23.630520448697933
# Time elapsed:                             8.33 mins
# KL between old and new distribution:      0.009997158
# Entropy:                                  0.30776072
# Surrogate loss:                           46.972397
#
# ********** Iteration 32 ************
# Rollout
# Made rollout
# Total number of episodes:                 12381
# Average sum of rewards per episode:       -87.81172291296625
# Std of rewards per episode:               24.816772340373266
# Time elapsed:                             8.60 mins
# KL between old and new distribution:      0.00999914
# Entropy:                                  0.303047
# Surrogate loss:                           47.202076
#
# ********** Iteration 33 ************
# Rollout
# Made rollout
# Total number of episodes:                 12928
# Average sum of rewards per episode:       -90.41133455210237
# Std of rewards per episode:               35.411874027898925
# Time elapsed:                             8.87 mins
# KL between old and new distribution:      0.009991341
# Entropy:                                  0.3311911
# Surrogate loss:                           51.768776
#
# ********** Iteration 34 ************
# Rollout
# Made rollout
# Total number of episodes:                 13475
# Average sum of rewards per episode:       -90.41133455210237
# Std of rewards per episode:               34.03231203948376
# Time elapsed:                             9.13 mins
# KL between old and new distribution:      0.009974855
# Entropy:                                  0.29674584
# Surrogate loss:                           51.32599
#
# ********** Iteration 35 ************
# Rollout
# Made rollout
# Total number of episodes:                 14038
# Average sum of rewards per episode:       -87.81172291296625
# Std of rewards per episode:               25.752822971326747
# Time elapsed:                             9.40 mins
# KL between old and new distribution:      0.009994804
# Entropy:                                  0.32095537
# Surrogate loss:                           47.4416
#
# ********** Iteration 36 ************
# Rollout
# Made rollout
# Total number of episodes:                 14587
# Average sum of rewards per episode:       -90.07650273224044
# Std of rewards per episode:               26.547986826252185
# Time elapsed:                             9.67 mins
# KL between old and new distribution:      0.009973816
# Entropy:                                  0.33008367
# Surrogate loss:                           48.70729
#
# ********** Iteration 37 ************
# Rollout
# Made rollout
# Total number of episodes:                 15126
# Average sum of rewards per episode:       -91.76623376623377
# Std of rewards per episode:               31.46628626847739
# Time elapsed:                             9.93 mins
# KL between old and new distribution:      0.009979778
# Entropy:                                  0.32986277
# Surrogate loss:                           51.04291
#
# ********** Iteration 38 ************
# Rollout
# Made rollout
# Total number of episodes:                 15667
# Average sum of rewards per episode:       -91.42329020332717
# Std of rewards per episode:               24.981400346989325
# Time elapsed:                             10.20 mins
# KL between old and new distribution:      0.009985494
# Entropy:                                  0.3237124
# Surrogate loss:                           48.902946
#
# ********** Iteration 39 ************
# Rollout
# Made rollout
# Total number of episodes:                 16210
# Average sum of rewards per episode:       -91.0828729281768
# Std of rewards per episode:               29.43918007700487
# Time elapsed:                             10.47 mins
# KL between old and new distribution:      0.009994028
# Entropy:                                  0.2742218
# Surrogate loss:                           50.0626
#
# ********** Iteration 40 ************
# Rollout
# Made rollout
# Total number of episodes:                 16763
# Average sum of rewards per episode:       -89.41772151898734
# Std of rewards per episode:               26.340190151775115
# Time elapsed:                             10.75 mins
# KL between old and new distribution:      0.009967745
# Entropy:                                  0.301388
# Surrogate loss:                           48.342175
#
# ********** Iteration 41 ************
# Rollout
# Made rollout
# Total number of episodes:                 17313
# Average sum of rewards per episode:       -89.91272727272727
# Std of rewards per episode:               29.56422318549878
# Time elapsed:                             11.01 mins
# KL between old and new distribution:      0.009980204
# Entropy:                                  0.27746686
# Surrogate loss:                           49.60345
#
# ********** Iteration 42 ************
# Rollout
# Made rollout
# Total number of episodes:                 17854
# Average sum of rewards per episode:       -91.42329020332717
# Std of rewards per episode:               28.244053454367297
# Time elapsed:                             11.28 mins
# KL between old and new distribution:      0.009993035
# Entropy:                                  0.28268263
# Surrogate loss:                           49.8327
#
# ********** Iteration 43 ************
# Rollout
# Made rollout
# Total number of episodes:                 18427
# Average sum of rewards per episode:       -86.26352530541013
# Std of rewards per episode:               28.3442810492786
# Time elapsed:                             11.55 mins
# KL between old and new distribution:      0.009994109
# Entropy:                                  0.28817144
# Surrogate loss:                           47.549816
#
# ********** Iteration 44 ************
# Rollout
# Made rollout
# Total number of episodes:                 18994
# Average sum of rewards per episode:       -87.18518518518519
# Std of rewards per episode:               24.967264477960807
# Time elapsed:                             11.81 mins
# KL between old and new distribution:      0.009993896
# Entropy:                                  0.28088236
# Surrogate loss:                           46.95939
#
# ********** Iteration 45 ************
# Rollout
# Made rollout
# Total number of episodes:                 19558
# Average sum of rewards per episode:       -87.65425531914893
# Std of rewards per episode:               26.478868189854023
# Time elapsed:                             12.08 mins
# KL between old and new distribution:      0.009999464
# Entropy:                                  0.2811798
# Surrogate loss:                           47.612156
#
# ********** Iteration 46 ************
# Rollout
# Made rollout
# Total number of episodes:                 20113
# Average sum of rewards per episode:       -89.0936936936937
# Std of rewards per episode:               30.857274696122182
# Time elapsed:                             12.35 mins
# KL between old and new distribution:      0.00999657
# Entropy:                                  0.2548965
# Surrogate loss:                           49.67326
#
# ********** Iteration 47 ************
# Rollout
# Made rollout
# Total number of episodes:                 20668
# Average sum of rewards per episode:       -89.0936936936937
# Std of rewards per episode:               30.475839727189598
# Time elapsed:                             12.61 mins
# KL between old and new distribution:      0.009996415
# Entropy:                                  0.2554376
# Surrogate loss:                           49.58097
#
# ********** Iteration 48 ************
# Rollout
# Made rollout
# Total number of episodes:                 21230
# Average sum of rewards per episode:       -87.97153024911032
# Std of rewards per episode:               32.72106704585276
# Time elapsed:                             12.88 mins
# KL between old and new distribution:      0.009996677
# Entropy:                                  0.25025347
# Surrogate loss:                           49.828144
#
# ********** Iteration 49 ************
# Rollout
# Made rollout
# Total number of episodes:                 21808
# Average sum of rewards per episode:       -85.50692041522491
# Std of rewards per episode:               23.28091100364752
# Time elapsed:                             13.14 mins
# KL between old and new distribution:      0.009996586
# Entropy:                                  0.26659518
# Surrogate loss:                           45.726566
#
# ********** Iteration 50 ************
# Rollout
# Made rollout
# Total number of episodes:                 22373
# Average sum of rewards per episode:       -87.49734513274336
# Std of rewards per episode:               25.94689082325969
# Time elapsed:                             13.41 mins
# KL between old and new distribution:      0.009993304
# Entropy:                                  0.24579655
# Surrogate loss:                           47.412724
#
# ********** Iteration 51 ************
# Rollout
# Made rollout
# Total number of episodes:                 22948
# Average sum of rewards per episode:       -85.96
# Std of rewards per episode:               34.98626016024005
# Time elapsed:                             13.68 mins
# KL between old and new distribution:      0.009968856
# Entropy:                                  0.26429307
# Surrogate loss:                           49.83132
#
# ********** Iteration 52 ************
# Rollout
# Made rollout
# Total number of episodes:                 23507
# Average sum of rewards per episode:       -88.45080500894454
# Std of rewards per episode:               38.09367037928423
# Time elapsed:                             13.94 mins
# KL between old and new distribution:      0.009985256
# Entropy:                                  0.2285634
# Surrogate loss:                           52.177124
#
# ********** Iteration 53 ************
# Rollout
# Made rollout
# Total number of episodes:                 24072
# Average sum of rewards per episode:       -87.49911504424779
# Std of rewards per episode:               34.4086130799268
# Time elapsed:                             14.21 mins
# KL between old and new distribution:      0.009998585
# Entropy:                                  0.22203171
# Surrogate loss:                           50.31213
#
# ********** Iteration 54 ************
# Rollout
# Made rollout
# Total number of episodes:                 24651
# Average sum of rewards per episode:       -85.35924006908463
# Std of rewards per episode:               30.6845130376082
# Time elapsed:                             14.48 mins
# KL between old and new distribution:      0.009976942
# Entropy:                                  0.21131563
# Surrogate loss:                           47.97388
#
# ********** Iteration 55 ************
# Rollout
# Made rollout
# Total number of episodes:                 25244
# Average sum of rewards per episode:       -83.31703204047217
# Std of rewards per episode:               24.307418349276226
# Time elapsed:                             14.74 mins
# KL between old and new distribution:      0.009977342
# Entropy:                                  0.21144082
# Surrogate loss:                           44.9974
#
# ********** Iteration 56 ************
# Rollout
# Made rollout
# Total number of episodes:                 25831
# Average sum of rewards per episode:       -84.18057921635435
# Std of rewards per episode:               25.359455312962268
# Time elapsed:                             15.01 mins
# KL between old and new distribution:      0.009994051
# Entropy:                                  0.18379316
# Surrogate loss:                           45.71873
# ********** Iteration 57 ************
# Rollout
# Made rollout
# Total number of episodes:                 26414
# Average sum of rewards per episode:       -84.77015437392797
# Std of rewards per episode:               36.28128154492625
# Time elapsed:                             15.28 mins
# KL between old and new distribution:      0.009993436
# Entropy:                                  0.17642756
# Surrogate loss:                           49.894226
#
# ********** Iteration 58 ************
# Rollout
# Made rollout
# Total number of episodes:                 26989
# Average sum of rewards per episode:       -85.96
# Std of rewards per episode:               32.105101314818846
# Time elapsed:                             15.55 mins
# KL between old and new distribution:      0.009977716
# Entropy:                                  0.14921056
# Surrogate loss:                           48.750237
#
# ********** Iteration 59 ************
# Rollout
# Made rollout
# Total number of episodes:                 27595
# Average sum of rewards per episode:       -81.50990099009901
# Std of rewards per episode:               21.11126584396946
# Time elapsed:                             15.81 mins
# KL between old and new distribution:      0.00999129
# Entropy:                                  0.15150562
# Surrogate loss:                           43.30939
#
# ********** Iteration 60 ************
# Rollout
# Made rollout
# Total number of episodes:                 28186
# Average sum of rewards per episode:       -83.60406091370558
# Std of rewards per episode:               26.438235343485157
# Time elapsed:                             16.08 mins
# KL between old and new distribution:      0.009991094
# Entropy:                                  0.13726865
# Surrogate loss:                           45.745174
#
# ********** Iteration 61 ************
# Rollout
# Made rollout
# Total number of episodes:                 28756
# Average sum of rewards per episode:       -86.72280701754386
# Std of rewards per episode:               32.148400508867425
# Time elapsed:                             16.35 mins
# KL between old and new distribution:      0.009986068
# Entropy:                                  0.12164829
# Surrogate loss:                           49.056015
#
# ********** Iteration 62 ************
# Rollout
# Made rollout
# Total number of episodes:                 29349
# Average sum of rewards per episode:       -83.3220910623946
# Std of rewards per episode:               31.241470488089217
# Time elapsed:                             16.61 mins
# KL between old and new distribution:      0.009985897
# Entropy:                                  0.13634159
# Surrogate loss:                           47.282215
#
# ********** Iteration 63 ************
# Rollout
# Made rollout
# Total number of episodes:                 29907
# Average sum of rewards per episode:       -88.60752688172043
# Std of rewards per episode:               33.73183962190546
# Time elapsed:                             16.88 mins
# KL between old and new distribution:      0.009978461
# Entropy:                                  0.13329245
# Surrogate loss:                           50.49209
#
# ********** Iteration 64 ************
# Rollout
# Made rollout
# Total number of episodes:                 30512
# Average sum of rewards per episode:       -81.64628099173554
# Std of rewards per episode:               24.778966824966275
# Time elapsed:                             17.15 mins
# KL between old and new distribution:      0.009966874
# Entropy:                                  0.13286614
# Surrogate loss:                           44.340027
#
# ********** Iteration 65 ************
# Rollout
# Made rollout
# Total number of episodes:                 31118
# Average sum of rewards per episode:       -81.51320132013201
# Std of rewards per episode:               32.156008795134035
# Time elapsed:                             17.41 mins
# KL between old and new distribution:      0.00999474
# Entropy:                                  0.12458853
# Surrogate loss:                           46.868225
#
# ********** Iteration 66 ************
# Rollout
# Made rollout
# Total number of episodes:                 31732
# Average sum of rewards per episode:       -80.43648208469055
# Std of rewards per episode:               28.43253122611397
# Time elapsed:                             17.68 mins
# KL between old and new distribution:      0.009979528
# Entropy:                                  0.115040556
# Surrogate loss:                           45.03609
#
# ********** Iteration 67 ************
# Rollout
# Made rollout
# Total number of episodes:                 32354
# Average sum of rewards per episode:       -79.38745980707395
# Std of rewards per episode:               18.378987293462934
# Time elapsed:                             17.95 mins
# KL between old and new distribution:      0.009991197
# Entropy:                                  0.11153226
# Surrogate loss:                           41.684834
#
# ********** Iteration 68 ************
# Rollout
# Made rollout
# Total number of episodes:                 32981
# Average sum of rewards per episode:       -78.7464114832536
# Std of rewards per episode:               17.288926650610875
# Time elapsed:                             18.21 mins
# KL between old and new distribution:      0.009986873
# Entropy:                                  0.12005892
# Surrogate loss:                           41.112793
#
# ********** Iteration 69 ************
# Rollout
# Made rollout
# Total number of episodes:                 33570
# Average sum of rewards per episode:       -83.893039049236
# Std of rewards per episode:               28.063844912511858
# Time elapsed:                             18.48 mins
# KL between old and new distribution:      0.009977572
# Entropy:                                  0.12789391
# Surrogate loss:                           46.400146
#
# ********** Iteration 70 ************
# Rollout
# Made rollout
# Total number of episodes:                 34184
# Average sum of rewards per episode:       -80.43485342019544
# Std of rewards per episode:               18.677831541758078
# Time elapsed:                             18.74 mins
# KL between old and new distribution:      0.009998312
# Entropy:                                  0.112036034
# Surrogate loss:                           42.221054
#
# ********** Iteration 71 ************
# Rollout
# Made rollout
# Total number of episodes:                 34801
# Average sum of rewards per episode:       -80.03889789303079
# Std of rewards per episode:               21.40309534145491
# Time elapsed:                             19.01 mins
# KL between old and new distribution:      0.009998087
# Entropy:                                  0.0996314
# Surrogate loss:                           42.74049
#
# ********** Iteration 72 ************
# Rollout
# Made rollout
# Total number of episodes:                 35408
# Average sum of rewards per episode:       -81.37891268533772
# Std of rewards per episode:               36.46886804131411
# Time elapsed:                             19.28 mins
# KL between old and new distribution:      0.009993977
# Entropy:                                  0.08750575
# Surrogate loss:                           48.60641
#
# ********** Iteration 73 ************
# Rollout
# Made rollout
# Total number of episodes:                 36037
# Average sum of rewards per episode:       -78.49443561208267
# Std of rewards per episode:               22.995998494956368
# Time elapsed:                             19.54 mins
# KL between old and new distribution:      0.009994201
# Entropy:                                  0.08796549
# Surrogate loss:                           42.42425
#
# ********** Iteration 74 ************
# Rollout
# Made rollout
# Total number of episodes:                 36672
# Average sum of rewards per episode:       -77.74173228346457
# Std of rewards per episode:               18.92536705744532
# Time elapsed:                             19.81 mins
# KL between old and new distribution:      0.009990934
# Entropy:                                  0.080832824
# Surrogate loss:                           40.999027
#
# ********** Iteration 75 ************
# Rollout
# Made rollout
# Total number of episodes:                 37303
# Average sum of rewards per episode:       -78.24247226624405
# Std of rewards per episode:               24.109822085360587
# Time elapsed:                             20.08 mins
# KL between old and new distribution:      0.009976936
# Entropy:                                  0.074514754
# Surrogate loss:                           42.693653
#
# ********** Iteration 76 ************
# Rollout
# Made rollout
# Total number of episodes:                 37942
# Average sum of rewards per episode:       -77.24882629107981
# Std of rewards per episode:               18.297379881174002
# Time elapsed:                             20.34 mins
# KL between old and new distribution:      0.009971207
# Entropy:                                  0.07387835
# Surrogate loss:                           40.646446
#
# ********** Iteration 77 ************
# Rollout
# Made rollout
# Total number of episodes:                 38585
# Average sum of rewards per episode:       -76.76205287713842
# Std of rewards per episode:               16.02110748527538
# Time elapsed:                             20.61 mins
# KL between old and new distribution:      0.009972673
# Entropy:                                  0.07455063
# Surrogate loss:                           39.92761
#
# ********** Iteration 78 ************
# Rollout
# Made rollout
# Total number of episodes:                 39239
# Average sum of rewards per episode:       -75.45412844036697
# Std of rewards per episode:               14.880570622074577
# Time elapsed:                             20.88 mins
# KL between old and new distribution:      0.009985121
# Entropy:                                  0.07252632
# Surrogate loss:                           39.070526
#
# ********** Iteration 79 ************
# Rollout
# Made rollout
# Total number of episodes:                 39863
# Average sum of rewards per episode:       -79.1298076923077
# Std of rewards per episode:               18.369100552047257
# Time elapsed:                             21.14 mins
# KL between old and new distribution:      0.009982478
# Entropy:                                  0.0742253
# Surrogate loss:                           41.468826
#
# ********** Iteration 80 ************
# Rollout
# Made rollout
# Total number of episodes:                 40506
# Average sum of rewards per episode:       -76.76205287713842
# Std of rewards per episode:               18.616895372144075
# Time elapsed:                             21.41 mins
# KL between old and new distribution:      0.009999854
# Entropy:                                  0.07081942
# Surrogate loss:                           40.480686
#
# ********** Iteration 81 ************
# Rollout
# Made rollout
# Total number of episodes:                 41154
# Average sum of rewards per episode:       -76.16358024691358
# Std of rewards per episode:               23.546927812435623
# Time elapsed:                             21.68 mins
# KL between old and new distribution:      0.009992461
# Entropy:                                  0.07145146
# Surrogate loss:                           41.536087
#
# ********** Iteration 82 ************
# Rollout
# Made rollout
# Total number of episodes:                 41795
# Average sum of rewards per episode:       -77.00468018720748
# Std of rewards per episode:               15.194371749237876
# Time elapsed:                             21.95 mins
# KL between old and new distribution:      0.009972299
# Entropy:                                  0.069752105
# Surrogate loss:                           39.889736
#
# ********** Iteration 83 ************
# Rollout
# Made rollout
# Total number of episodes:                 42444
# Average sum of rewards per episode:       -76.04314329738058
# Std of rewards per episode:               17.27020787669544
# Time elapsed:                             22.21 mins
# KL between old and new distribution:      0.009980889
# Entropy:                                  0.06315585
# Surrogate loss:                           39.86561
#
# ********** Iteration 84 ************
# Rollout
# Made rollout
# Total number of episodes:                 43084
# Average sum of rewards per episode:       -77.1265625
# Std of rewards per episode:               19.180994354662477
# Time elapsed:                             22.48 mins
# KL between old and new distribution:      0.009985184
# Entropy:                                  0.06931124
# Surrogate loss:                           40.72394
#
# ********** Iteration 85 ************
# Rollout
# Made rollout
# Total number of episodes:                 43740
# Average sum of rewards per episode:       -75.22103658536585
# Std of rewards per episode:               15.018634243340733
# Time elapsed:                             22.75 mins
# KL between old and new distribution:      0.009998507
# Entropy:                                  0.062871404
# Surrogate loss:                           38.954685
#
# ********** Iteration 86 ************
# Rollout
# Made rollout
# Total number of episodes:                 44357
# Average sum of rewards per episode:       -80.03889789303079
# Std of rewards per episode:               23.082933645655533
# Time elapsed:                             23.01 mins
# KL between old and new distribution:      0.009980573
# Entropy:                                  0.066108786
# Surrogate loss:                           43.1778
#
# ********** Iteration 87 ************
# Rollout
# Made rollout
# Total number of episodes:                 44966
# Average sum of rewards per episode:       -81.10509031198687
# Std of rewards per episode:               25.972300333196422
# Time elapsed:                             23.28 mins
# KL between old and new distribution:      0.009994417
# Entropy:                                  0.06775423
# Surrogate loss:                           44.516636
#
# ********** Iteration 88 ************
# Rollout
# Made rollout
# Total number of episodes:                 45599
# Average sum of rewards per episode:       -77.99210110584518
# Std of rewards per episode:               24.411912784350296
# Time elapsed:                             23.55 mins
# KL between old and new distribution:      0.009987403
# Entropy:                                  0.06052063
# Surrogate loss:                           42.669266
#
# ********** Iteration 89 ************
# Rollout
# Made rollout
# Total number of episodes:                 46254
# Average sum of rewards per episode:       -75.33740458015266
# Std of rewards per episode:               13.325773316591043
# Time elapsed:                             23.81 mins
# KL between old and new distribution:      0.00999339
# Entropy:                                  0.06399235
# Surrogate loss:                           38.67643
#
# ********** Iteration 90 ************
# Rollout
# Made rollout
# Total number of episodes:                 46889
# Average sum of rewards per episode:       -77.74173228346457
# Std of rewards per episode:               19.824412060251046
# Time elapsed:                             24.08 mins
# KL between old and new distribution:      0.00999838
# Entropy:                                  0.05903208
# Surrogate loss:                           41.24446
#
# ********** Iteration 91 ************
# Rollout
# Made rollout
# Total number of episodes:                 47541
# Average sum of rewards per episode:       -75.68865030674847
# Std of rewards per episode:               15.483109539120816
# Time elapsed:                             24.35 mins
# KL between old and new distribution:      0.009982421
# Entropy:                                  0.0542023
# Surrogate loss:                           39.347256
#
# ********** Iteration 92 ************
# Rollout
# Made rollout
# Total number of episodes:                 48186
# Average sum of rewards per episode:       -76.52093023255814
# Std of rewards per episode:               17.746927562098104
# Time elapsed:                             24.61 mins
# KL between old and new distribution:      0.009976365
# Entropy:                                  0.052219667
# Surrogate loss:                           40.150475
#
# ********** Iteration 93 ************
# Rollout
# Made rollout
# Total number of episodes:                 48850
# Average sum of rewards per episode:       -74.30271084337349
# Std of rewards per episode:               13.48393483651655
# Time elapsed:                             24.88 mins
# KL between old and new distribution:      0.009985274
# Entropy:                                  0.047362465
# Surrogate loss:                           38.298313
#
# ********** Iteration 94 ************
# Rollout
# Made rollout
# Total number of episodes:                 49492
# Average sum of rewards per episode:       -76.88317757009345
# Std of rewards per episode:               16.137369718437018
# Time elapsed:                             25.14 mins
# KL between old and new distribution:      0.009977268
# Entropy:                                  0.056727987
# Surrogate loss:                           39.95376
#
# ********** Iteration 95 ************
# Rollout
# Made rollout
# Total number of episodes:                 50128
# Average sum of rewards per episode:       -77.61792452830188
# Std of rewards per episode:               19.604026494878905
# Time elapsed:                             25.41 mins
# KL between old and new distribution:      0.009984415
# Entropy:                                  0.055282626
# Surrogate loss:                           41.1621
#
# ********** Iteration 96 ************
# Rollout
# Made rollout
# Total number of episodes:                 50762
# Average sum of rewards per episode:       -77.86593059936908
# Std of rewards per episode:               21.543646699038103
# Time elapsed:                             25.68 mins
# KL between old and new distribution:      0.00999794
# Entropy:                                  0.055094395
# Surrogate loss:                           41.740616
#
# ********** Iteration 97 ************
# Rollout
# Made rollout
# Total number of episodes:                 51379
# Average sum of rewards per episode:       -80.03889789303079
# Std of rewards per episode:               19.16748100614305
# Time elapsed:                             25.94 mins
# KL between old and new distribution:      0.009982865
# Entropy:                                  0.04796422
# Surrogate loss:                           42.1818
#
# ********** Iteration 98 ************
# Rollout
# Made rollout
# Total number of episodes:                 52027
# Average sum of rewards per episode:       -76.16203703703704
# Std of rewards per episode:               13.773520069674976
# Time elapsed:                             26.21 mins
# KL between old and new distribution:      0.009972547
# Entropy:                                  0.046591226
# Surrogate loss:                           39.225468
#
# ********** Iteration 99 ************
# Rollout
# Made rollout
# Total number of episodes:                 52678
# Average sum of rewards per episode:       -75.80645161290323
# Std of rewards per episode:               15.064001346391834
# Time elapsed:                             26.48 mins
# KL between old and new distribution:      0.009984838
# Entropy:                                  0.041953385
# Surrogate loss:                           39.285374
#
# ********** Iteration 100 ************
# Rollout
# Made rollout
# Total number of episodes:                 53330
# Average sum of rewards per episode:       -75.68865030674847
# Std of rewards per episode:               16.172279737892843
# Time elapsed:                             26.74 mins
# KL between old and new distribution:      0.009993511
# Entropy:                                  0.0397669
# Surrogate loss:                           39.4438
#
# ********** Iteration 101 ************
# Rollout
# Made rollout
# Total number of episodes:                 53990
# Average sum of rewards per episode:       -74.75909090909092
# Std of rewards per episode:               20.992231443839778
# Time elapsed:                             27.01 mins
# KL between old and new distribution:      0.009998907
# Entropy:                                  0.041494213
# Surrogate loss:                           40.19762
#
# ********** Iteration 102 ************
# Rollout
# Made rollout
# Total number of episodes:                 54648
# Average sum of rewards per episode:       -74.98936170212765
# Std of rewards per episode:               14.896549320545518
# Time elapsed:                             27.28 mins
# KL between old and new distribution:      0.0099828495
# Entropy:                                  0.03951361
# Surrogate loss:                           38.846294
#
# ********** Iteration 103 ************
# Rollout
# Made rollout
# Total number of episodes:                 55315
# Average sum of rewards per episode:       -73.9640179910045
# Std of rewards per episode:               15.318269483126915
# Time elapsed:                             27.54 mins
# KL between old and new distribution:      0.0099795805
# Entropy:                                  0.035203833
# Surrogate loss:                           38.43234
#
# ********** Iteration 104 ************
# Rollout
# Made rollout
# Total number of episodes:                 55978
# Average sum of rewards per episode:       -74.41628959276018
# Std of rewards per episode:               13.584721259301137
# Time elapsed:                             27.81 mins
# KL between old and new distribution:      0.009980626
# Entropy:                                  0.038572192
# Surrogate loss:                           38.351627
#
# ********** Iteration 105 ************
# Rollout
# Made rollout
# Total number of episodes:                 56642
# Average sum of rewards per episode:       -74.30271084337349
# Std of rewards per episode:               15.082112356472349
# Time elapsed:                             28.08 mins
# KL between old and new distribution:      0.009984332
# Entropy:                                  0.038516145
# Surrogate loss:                           38.59986
#
# ********** Iteration 106 ************
# Rollout
# Made rollout
# Total number of episodes:                 57305
# Average sum of rewards per episode:       -74.41628959276018
# Std of rewards per episode:               16.449983797155976
# Time elapsed:                             28.35 mins
# KL between old and new distribution:      0.009979171
# Entropy:                                  0.034189664
# Surrogate loss:                           38.878395
#
# ********** Iteration 107 ************
# Rollout
# Made rollout
# Total number of episodes:                 57980
# Average sum of rewards per episode:       -73.07555555555555
# Std of rewards per episode:               12.34558830583962
# Time elapsed:                             28.61 mins
# KL between old and new distribution:      0.00998427
# Entropy:                                  0.035411272
# Surrogate loss:                           37.499077
#
# ********** Iteration 108 ************
# Rollout
# Made rollout
# Total number of episodes:                 58647
# Average sum of rewards per episode:       -73.9640179910045
# Std of rewards per episode:               12.645740281772323
# Time elapsed:                             28.88 mins
# KL between old and new distribution:      0.009979577
# Entropy:                                  0.032766197
# Surrogate loss:                           37.950256
#
# ********** Iteration 109 ************
# Rollout
# Made rollout
# Total number of episodes:                 59319
# Average sum of rewards per episode:       -73.40625
# Std of rewards per episode:               12.945403541113034
# Time elapsed:                             29.14 mins
# KL between old and new distribution:      0.009974232
# Entropy:                                  0.041248057
# Surrogate loss:                           37.622456
#
# ********** Iteration 110 ************
# Rollout
# Made rollout
# Total number of episodes:                 59965
# Average sum of rewards per episode:       -76.40092879256966
# ...
# Time elapsed:                             103.52 mins
# KL between old and new distribution:      0.0036607333
# Entropy:                                  0.013368606
# Surrogate loss:                           35.480217
#
# ********** Iteration 383 ************
# Rollout
# Made rollout
# Total number of episodes:                 246986
# Average sum of rewards per episode:       -69.62288135593221
# Std of rewards per episode:               9.839123258707957
# Time elapsed:                             103.80 mins
# KL between old and new distribution:      0.009983272
# Entropy:                                  0.012138517
# Surrogate loss:                           35.45518
#
# ********** Iteration 384 ************
# Rollout
# Made rollout
# Total number of episodes:                 247687
# Average sum of rewards per episode:       -70.32810271041369
# Std of rewards per episode:               9.826783422592005
# Time elapsed:                             104.07 mins
# KL between old and new distribution:      0.009990645
# Entropy:                                  0.010915502
# Surrogate loss:                           35.780125
#
# ********** Iteration 385 ************
# Rollout
# Made rollout
# Total number of episodes:                 248396
# Average sum of rewards per episode:       -69.52327221438647
# Std of rewards per episode:               10.579597285073461
# Time elapsed:                             104.34 mins
# KL between old and new distribution:      0.009962382
# Entropy:                                  0.010908556
# Surrogate loss:                           35.455242
#
# ********** Iteration 386 ************
# Rollout
# Made rollout
# Total number of episodes:                 249114
# Average sum of rewards per episode:       -68.63927576601671
# Std of rewards per episode:               9.6132432754062
# Time elapsed:                             104.62 mins
# KL between old and new distribution:      0.009607597
# Entropy:                                  0.011841272
# Surrogate loss:                           34.899166
#
# ********** Iteration 387 ************
# Rollout
# Made rollout
# Total number of episodes:                 249823
# Average sum of rewards per episode:       -69.52327221438647
# Std of rewards per episode:               10.71261110482893
# Time elapsed:                             104.89 mins
# KL between old and new distribution:      0.00998989
# Entropy:                                  0.011223042
# Surrogate loss:                           35.4266
#
# ********** Iteration 388 ************
# Rollout
# Made rollout
# Total number of episodes:                 250536
# Average sum of rewards per episode:       -69.12762973352034
# Std of rewards per episode:               8.017983442063752
# Time elapsed:                             105.16 mins
# KL between old and new distribution:      0.009967368
# Entropy:                                  0.016568288
# Surrogate loss:                           34.880066
#
# ********** Iteration 389 ************
# Rollout
# Made rollout
# Total number of episodes:                 251243
# Average sum of rewards per episode:       -69.72277227722772
# Std of rewards per episode:               9.552628241343207
# Time elapsed:                             105.43 mins
# KL between old and new distribution:      0.009982963
# Entropy:                                  0.014304277
# Surrogate loss:                           35.43665
#
# ********** Iteration 390 ************
# Rollout
# Made rollout
# Total number of episodes:                 251938
# Average sum of rewards per episode:       -70.9453237410072
# Std of rewards per episode:               19.76938707150431
# Time elapsed:                             105.70 mins
# KL between old and new distribution:      0.009997852
# Entropy:                                  0.013895457
# Surrogate loss:                           38.143757
#
# ********** Iteration 391 ************
# Rollout
# Made rollout
# Total number of episodes:                 252648
# Average sum of rewards per episode:       -69.42394366197183
# Std of rewards per episode:               11.15444665692468
# Time elapsed:                             105.97 mins
# KL between old and new distribution:      0.009990273
# Entropy:                                  0.012565585
# Surrogate loss:                           35.537693
#
# ********** Iteration 392 ************
# Rollout
# Made rollout
# Total number of episodes:                 253355
# Average sum of rewards per episode:       -69.72277227722772
# Std of rewards per episode:               9.297355813842396
# Time elapsed:                             106.24 mins
# KL between old and new distribution:      0.007218006
# Entropy:                                  0.012194849
# Surrogate loss:                           35.412537
#
# ********** Iteration 393 ************
# Rollout
# Made rollout
# Total number of episodes:                 254066
# Average sum of rewards per episode:       -69.32489451476793
# Std of rewards per episode:               8.18182519528157
# Time elapsed:                             106.51 mins
# KL between old and new distribution:      0.009975
# Entropy:                                  0.014455388
# Surrogate loss:                           34.97782
#
# ********** Iteration 394 ************
# Rollout
# Made rollout
# Total number of episodes:                 254753
# Average sum of rewards per episode:       -71.78165938864629
# Std of rewards per episode:               15.982397928178328
# Time elapsed:                             106.78 mins
# KL between old and new distribution:      0.009982926
# Entropy:                                  0.015230912
# Surrogate loss:                           37.48522
#
# ********** Iteration 395 ************
# Rollout
# Made rollout
# Total number of episodes:                 255441
# Average sum of rewards per episode:       -71.67587209302326
# Std of rewards per episode:               17.361692640191425
# Time elapsed:                             107.05 mins
# KL between old and new distribution:      0.009986758
# Entropy:                                  0.014509836
# Surrogate loss:                           37.79211
#
# ********** Iteration 396 ************
# Rollout
# Made rollout
# Total number of episodes:                 256134
# Average sum of rewards per episode:       -71.15151515151516
# Std of rewards per episode:               14.644074044838847
# Time elapsed:                             107.32 mins
# KL between old and new distribution:      0.00997757
# Entropy:                                  0.012771313
# Surrogate loss:                           36.9705
#
# ********** Iteration 397 ************
# Rollout
# Made rollout
# Total number of episodes:                 256842
# Average sum of rewards per episode:       -69.62288135593221
# Std of rewards per episode:               10.500626112757985
# Time elapsed:                             107.59 mins
# KL between old and new distribution:      0.009972204
# Entropy:                                  0.014257772
# Surrogate loss:                           35.51614
#
# ********** Iteration 398 ************
# Rollout
# Made rollout
# Total number of episodes:                 257528
# Average sum of rewards per episode:       -71.88775510204081
# Std of rewards per episode:               13.326268866385995
# Time elapsed:                             107.87 mins
# KL between old and new distribution:      0.009983617
# Entropy:                                  0.014879377
# Surrogate loss:                           37.04363
#
# ********** Iteration 399 ************
# Rollout
# Made rollout
# Total number of episodes:                 258223
# Average sum of rewards per episode:       -70.94388489208633
# Std of rewards per episode:               14.071391023607728
# Time elapsed:                             108.14 mins
# KL between old and new distribution:      0.009995521
# Entropy:                                  0.01216886
# Surrogate loss:                           36.766994
#
# ********** Iteration 400 ************
# Rollout
# Made rollout
# Total number of episodes:                 258928
# Average sum of rewards per episode:       -69.92340425531916
# Std of rewards per episode:               11.159695961044845
# Time elapsed:                             108.42 mins
# KL between old and new distribution:      0.009986513
# Entropy:                                  0.012148346
# Surrogate loss:                           35.763443
#
# ********** Iteration 401 ************
# Rollout
# Made rollout
# Total number of episodes:                 259637
# Average sum of rewards per episode:       -69.52327221438647
# Std of rewards per episode:               10.457035882493715
# Time elapsed:                             108.69 mins
# KL between old and new distribution:      0.009975438
# Entropy:                                  0.013197124
# Surrogate loss:                           35.472927
#
# ********** Iteration 402 ************
# Rollout
# Made rollout
# Total number of episodes:                 260338
# Average sum of rewards per episode:       -70.32810271041369
# Std of rewards per episode:               10.890096560866658
# Time elapsed:                             108.96 mins
# KL between old and new distribution:      0.009631526
# Entropy:                                  0.011770497
# Surrogate loss:                           35.936783
#
# ********** Iteration 403 ************
# Rollout
# Made rollout
# Total number of episodes:                 261055
# Average sum of rewards per episode:       -68.73640167364017
# Std of rewards per episode:               7.664257087505114
# Time elapsed:                             109.24 mins
# KL between old and new distribution:      0.009988035
# Entropy:                                  0.010615473
# Surrogate loss:                           34.69407
#
# ********** Iteration 404 ************
# Rollout
# Made rollout
# Total number of episodes:                 261761
# Average sum of rewards per episode:       -69.8229461756374
# Std of rewards per episode:               10.06753880030698
# Time elapsed:                             109.51 mins
# KL between old and new distribution:      0.0099861445
# Entropy:                                  0.009093364
# Surrogate loss:                           35.52371
#
# ********** Iteration 405 ************
# Rollout
# Made rollout
# Total number of episodes:                 262461
# Average sum of rewards per episode:       -70.43
# Std of rewards per episode:               12.597821240198641
# Time elapsed:                             109.79 mins
# KL between old and new distribution:      0.0075783366
# Entropy:                                  0.010929533
# Surrogate loss:                           36.315674
#
# ********** Iteration 406 ************
# Rollout
# Made rollout
# Total number of episodes:                 263163
# Average sum of rewards per episode:       -70.22649572649573
# Std of rewards per episode:               10.184969316143249
# Time elapsed:                             110.06 mins
# KL between old and new distribution:      0.009983376
# Entropy:                                  0.010384491
# Surrogate loss:                           35.79387
#
# ********** Iteration 407 ************
# Rollout
# Made rollout
# Total number of episodes:                 263872
# Average sum of rewards per episode:       -69.52327221438647
# Std of rewards per episode:               11.775094201466198
# Time elapsed:                             110.33 mins
# KL between old and new distribution:      0.009992339
# Entropy:                                  0.010884163
# Surrogate loss:                           35.68036
#
# ********** Iteration 408 ************
# Rollout
# Made rollout
# Total number of episodes:                 264566
# Average sum of rewards per episode:       -71.04755043227665
# Std of rewards per episode:               12.77444714119976
# Time elapsed:                             110.61 mins
# KL between old and new distribution:      0.009974147
# Entropy:                                  0.012299502
# Surrogate loss:                           36.56492
#
# ********** Iteration 409 ************
# Rollout
# Made rollout
# Total number of episodes:                 265257
# Average sum of rewards per episode:       -71.3603473227207
# Std of rewards per episode:               11.692222452155272
# Time elapsed:                             110.87 mins
# KL between old and new distribution:      0.009980133
# Entropy:                                  0.011174643
# Surrogate loss:                           36.535404
#
# ********** Iteration 410 ************
# Rollout
# Made rollout
# Total number of episodes:                 265958
# Average sum of rewards per episode:       -70.32810271041369
# Std of rewards per episode:               9.349036000913102
# Time elapsed:                             111.14 mins
# KL between old and new distribution:      0.009991115
# Entropy:                                  0.010362214
# Surrogate loss:                           35.609295
#
# ********** Iteration 411 ************
# Rollout
# Made rollout
# Total number of episodes:                 266647
# Average sum of rewards per episode:       -71.57039187227866
# Std of rewards per episode:               14.931427002409846
# Time elapsed:                             111.41 mins
# KL between old and new distribution:      0.009979915
# Entropy:                                  0.009930007
# Surrogate loss:                           37.29304
#
# ********** Iteration 412 ************
# Rollout
# Made rollout
# Total number of episodes:                 267341
# Average sum of rewards per episode:       -71.04755043227665
# Std of rewards per episode:               11.181978530453623
# Time elapsed:                             111.68 mins
# KL between old and new distribution:      0.009972677
# Entropy:                                  0.009765736
# Surrogate loss:                           36.265194
#
# ********** Iteration 413 ************
# Rollout
# Made rollout
# Total number of episodes:                 268040
# Average sum of rewards per episode:       -70.53218884120172
# Std of rewards per episode:               11.792800218054108
# Time elapsed:                             111.95 mins
# KL between old and new distribution:      0.006884601
# Entropy:                                  0.010004497
# Surrogate loss:                           36.204052
#
# ********** Iteration 414 ************
# Rollout
# Made rollout
# Total number of episodes:                 268742
# Average sum of rewards per episode:       -70.22649572649573
# Std of rewards per episode:               10.599345997905488
# Time elapsed:                             112.22 mins
# KL between old and new distribution:      0.009971191
# Entropy:                                  0.010086287
# Surrogate loss:                           35.80157
#
# ********** Iteration 415 ************
# Rollout
# Made rollout
# Total number of episodes:                 269443
# Average sum of rewards per episode:       -70.32810271041369
# Std of rewards per episode:               9.42093280199132
# Time elapsed:                             112.49 mins
# KL between old and new distribution:      0.009999699
# Entropy:                                  0.01108685
# Surrogate loss:                           35.7036
#
# ********** Iteration 416 ************
# Rollout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-4e6dbda4efe8> in <module>
#      15     # Generating paths.
#      16     print("Rollout")
# ---> 17     paths = rollout(env, agent)
#      18     print("Made rollout")
#      19
#
# <ipython-input-56-1387065954a1> in rollout(env, agent, max_pathlength, n_timesteps)
#      14         obervation = env.reset()
#      15         for _ in range(max_pathlength):
# ---> 16             action, policy = agent.act(obervation)
#      17             obervations.append(obervation)
#      18             actions.append(action)
#
# <ipython-input-51-ab6a6f6f72bc> in act(self, obs, sample)
#      51         '''
#      52
# ---> 53         probs = self.get_probs(Variable(torch.FloatTensor([obs]))).data.numpy()
#      54
#      55         if sample:
#
# <ipython-input-51-ab6a6f6f72bc> in get_probs(self, states)
#      41         '''
#      42
# ---> 43         return torch.exp(self.forward(states))
#      44
#      45     def act(self, obs, sample=True):
#
# KeyboardInterrupt:

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.org/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the mcts seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/week10_planning/seminar_MCTS.ipynb).
#
# You can read more about in the [TRPO article](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cummulative rewards similar to `get_cummulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gym.openai.com/envs#mujoco)
# * [Box2d robot](https://gym.openai.com/envs/BipedalWalker-v2)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use fully factorized gaussian (basically a vector of gaussians).
#
# __bonus task__: compare performance of continuous action space method to action space discretization
